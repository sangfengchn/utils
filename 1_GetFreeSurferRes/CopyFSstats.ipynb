# %%
from pathlib import Path
import pandas as pd
import re
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s: %(message)s')

subDir = '/brain/babri_in/sangf/Projects/D_desc-babri/derivatives/freesurfer'
subDir = Path(subDir)
atlas = 'aseg'

def func_GetAseg(file):
    with open(file, 'r') as f:
        lines = [i for i in f.readlines() if len(i) != 0]
    # logging.info(lines)
    resRow = {}
    for i in lines:
        if re.match('# Measure lhCortex,', i):
            resRow['lhCortex'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure rhCortex,', i):
            resRow['rhCortex'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure Cortex,', i):
            resRow['Cortex'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure lhCerebralWhiteMatter,', i):
            resRow['lhCerebralWhiteMatter'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure rhCerebralWhiteMatter,', i):
            resRow['rhCerebralWhiteMatter'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure CerebralWhiteMatter,', i):
            resRow['CerebralWhiteMatter'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure EstimatedTotalIntraCranialVol,', i):
            resRow['EstimatedTotalIntraCranialVol'] = [float(re.split(',', i)[-2])]
        if not re.match('#', i):
            tmpRegion = re.split(r'\s+', i.strip())[4]
            resRow[f'{tmpRegion}_Volume_mm3'] = [re.split(r'\s+', i.strip())[3]]
            
    # logging.info(resRow)
    return pd.DataFrame(resRow)

def func_GetAparc(file, hemi='lh'):
    with open(file, 'r') as f:
        lines = [i for i in f.readlines() if len(i) != 0]
    # logging.info(lines)
    resRow = {}
    for i in lines:
        if re.match('# Measure Cortex, WhiteSurfArea,', i):
            resRow[f'{hemi}_WhiteSurfArea,'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure Cortex, MeanThickness,', i):
            resRow[f'{hemi}_MeanThickness'] = [float(re.split(',', i)[-2])]
        elif re.match('# Measure EstimatedTotalIntraCranialVol,', i):
            resRow[f'{hemi}_EstimatedTotalIntraCranialVol'] = [float(re.split(',', i)[-2])]
        if not re.match('#', i):
            tmpRegion = re.split(r'\s+', i.strip())[0]
            resRow[f'{hemi}_{tmpRegion}_NumVert'] = [re.split(r'\s+', i.strip())[1]]
            resRow[f'{hemi}_{tmpRegion}_SurfArea'] = [re.split(r'\s+', i.strip())[2]]
            resRow[f'{hemi}_{tmpRegion}_GrayVol'] = [re.split(r'\s+', i.strip())[3]]
            resRow[f'{hemi}_{tmpRegion}_ThickAvg'] = [re.split(r'\s+', i.strip())[4]]
            resRow[f'{hemi}_{tmpRegion}_ThickStd'] = [re.split(r'\s+', i.strip())[5]]
            resRow[f'{hemi}_{tmpRegion}_MeanCurv'] = [re.split(r'\s+', i.strip())[6]]
            resRow[f'{hemi}_{tmpRegion}_GausCurv'] = [re.split(r'\s+', i.strip())[7]]
            resRow[f'{hemi}_{tmpRegion}_FoldInd'] = [re.split(r'\s+', i.strip())[8]]
            resRow[f'{hemi}_{tmpRegion}_CurvInd'] = [re.split(r'\s+', i.strip())[9]]
            
    # logging.info(resRow)
    return pd.DataFrame(resRow)

resDf = pd.DataFrame()
for i in subDir.glob('sub-*'):
    subId = i.name
    logging.info(subId)
    
    if atlas == 'aseg':
        subPath = i.joinpath('stats/aseg.stats')
        if not subPath.exists(): continue
        subDf = func_GetAseg(subPath.resolve())
    elif atlas == 'aparc':
        subPath = i.joinpath('stats/lh.aparc.stats')
        if not subPath.exists(): continue
        subDf_lh = func_GetAparc(subPath.resolve(), hemi='lh')
        subDf_rh = func_GetAparc(str(subPath.resolve()).replace('lh', 'rh'), hemi='rh')
        subDf = pd.concat([subDf_lh, subDf_rh], axis=1)
    elif atlas == 'aparc.a2009s':
        subPath = i.joinpath('stats/lh.aparc.a2009s.stats')
        if not subPath.exists(): continue
        subDf_lh = func_GetAparc(subPath.resolve(), hemi='lh')
        subDf_rh = func_GetAparc(str(subPath.resolve()).replace('lh', 'rh'), hemi='rh')
        subDf = pd.concat([subDf_lh, subDf_rh], axis=1)
        
    subDf['participant_id'] = [subId]
    resDf = pd.concat([resDf, subDf], ignore_index=True)

resDf.to_csv(f'Res_atlas-{atlas}.csv', index=False)
# Out:
# 2024-12-04 14:59:31,270: sub-31157
# 2024-12-04 14:59:31,273: {'lh_WhiteSurfArea,': [74372.9], 'lh_MeanThickness': [2.48902], 'lh_EstimatedTotalIntraCranialVol': [1296541.55381], 'lh_bankssts_NumVert': ['1577'], 'lh_bankssts_SurfArea': ['906'], 'lh_bankssts_GrayVol': ['2059'], 'lh_bankssts_ThickAvg': ['2.409'], 'lh_bankssts_ThickStd': ['0.465'], 'lh_bankssts_MeanCurv': ['0.093'], 'lh_bankssts_GausCurv': ['0.028'], 'lh_bankssts_FoldInd': ['13'], 'lh_bankssts_CurvInd': ['2.3'], 'lh_caudalanteriorcingulate_NumVert': ['783'], 'lh_caudalanteriorcingulate_SurfArea': ['426'], 'lh_caudalanteriorcingulate_GrayVol': ['1370'], 'lh_caudalanteriorcingulate_ThickAvg': ['2.808'], 'lh_caudalanteriorcingulate_ThickStd': ['0.732'], 'lh_caudalanteriorcingulate_MeanCurv': ['0.116'], 'lh_caudalanteriorcingulate_GausCurv': ['0.026'], 'lh_caudalanteriorcingulate_FoldInd': ['9'], 'lh_caudalanteriorcingulate_CurvInd': ['1.0'], 'lh_caudalmiddlefrontal_NumVert': ['3432'], 'lh_caudalmiddlefrontal_SurfArea': ['1809'], 'lh_caudalmiddlefrontal_GrayVol': ['4850'], 'lh_caudalmiddlefrontal_ThickAvg': ['2.439'], 'lh_caudalmiddlefrontal_ThickStd': ['0.510'], 'lh_caudalmiddlefrontal_MeanCurv': ['0.105'], 'lh_caudalmiddlefrontal_GausCurv': ['0.029'], 'lh_caudalmiddlefrontal_FoldInd': ['33'], 'lh_caudalmiddlefrontal_CurvInd': ['4.3'], 'lh_cuneus_NumVert': ['2637'], 'lh_cuneus_SurfArea': ['1274'], 'lh_cuneus_GrayVol': ['3283'], 'lh_cuneus_ThickAvg': ['2.148'], 'lh_cuneus_ThickStd': ['0.504'], 'lh_cuneus_MeanCurv': ['0.108'], 'lh_cuneus_GausCurv': ['0.029'], 'lh_cuneus_FoldInd': ['28'], 'lh_cuneus_CurvInd': ['3.5'], 'lh_entorhinal_NumVert': ['983'], 'lh_entorhinal_SurfArea': ['497'], 'lh_entorhinal_GrayVol': ['2358'], 'lh_entorhinal_ThickAvg': ['3.157'], 'lh_entorhinal_ThickStd': ['0.745'], 'lh_entorhinal_MeanCurv': ['0.123'], 'lh_entorhinal_GausCurv': ['0.056'], 'lh_entorhinal_FoldInd': ['16'], 'lh_entorhinal_CurvInd': ['2.0'], 'lh_fusiform_NumVert': ['5296'], 'lh_fusiform_SurfArea': ['2748'], 'lh_fusiform_GrayVol': ['9316'], 'lh_fusiform_ThickAvg': ['2.834'], 'lh_fusiform_ThickStd': ['0.609'], 'lh_fusiform_MeanCurv': ['0.119'], 'lh_fusiform_GausCurv': ['0.039'], 'lh_fusiform_FoldInd': ['76'], 'lh_fusiform_CurvInd': ['9.2'], 'lh_inferiorparietal_NumVert': ['7010'], 'lh_inferiorparietal_SurfArea': ['3731'], 'lh_inferiorparietal_GrayVol': ['10878'], 'lh_inferiorparietal_ThickAvg': ['2.449'], 'lh_inferiorparietal_ThickStd': ['0.633'], 'lh_inferiorparietal_MeanCurv': ['0.115'], 'lh_inferiorparietal_GausCurv': ['0.033'], 'lh_inferiorparietal_FoldInd': ['105'], 'lh_inferiorparietal_CurvInd': ['9.8'], 'lh_inferiortemporal_NumVert': ['6105'], 'lh_inferiortemporal_SurfArea': ['3159'], 'lh_inferiortemporal_GrayVol': ['12924'], 'lh_inferiortemporal_ThickAvg': ['2.887'], 'lh_inferiortemporal_ThickStd': ['0.744'], 'lh_inferiortemporal_MeanCurv': ['0.120'], 'lh_inferiortemporal_GausCurv': ['0.040'], 'lh_inferiortemporal_FoldInd': ['89'], 'lh_inferiortemporal_CurvInd': ['10.8'], 'lh_isthmuscingulate_NumVert': ['1516'], 'lh_isthmuscingulate_SurfArea': ['746'], 'lh_isthmuscingulate_GrayVol': ['2033'], 'lh_isthmuscingulate_ThickAvg': ['2.424'], 'lh_isthmuscingulate_ThickStd': ['0.899'], 'lh_isthmuscingulate_MeanCurv': ['0.096'], 'lh_isthmuscingulate_GausCurv': ['0.027'], 'lh_isthmuscingulate_FoldInd': ['15'], 'lh_isthmuscingulate_CurvInd': ['1.5'], 'lh_lateraloccipital_NumVert': ['9510'], 'lh_lateraloccipital_SurfArea': ['4838'], 'lh_lateraloccipital_GrayVol': ['12994'], 'lh_lateraloccipital_ThickAvg': ['2.258'], 'lh_lateraloccipital_ThickStd': ['0.602'], 'lh_lateraloccipital_MeanCurv': ['0.132'], 'lh_lateraloccipital_GausCurv': ['0.037'], 'lh_lateraloccipital_FoldInd': ['150'], 'lh_lateraloccipital_CurvInd': ['14.7'], 'lh_lateralorbitofrontal_NumVert': ['4166'], 'lh_lateralorbitofrontal_SurfArea': ['2114'], 'lh_lateralorbitofrontal_GrayVol': ['6275'], 'lh_lateralorbitofrontal_ThickAvg': ['2.585'], 'lh_lateralorbitofrontal_ThickStd': ['0.678'], 'lh_lateralorbitofrontal_MeanCurv': ['0.106'], 'lh_lateralorbitofrontal_Gaus ...
# 2024-12-04 14:59:31,284: {'rh_WhiteSurfArea,': [74745.1], 'rh_MeanThickness': [2.52365], 'rh_EstimatedTotalIntraCranialVol': [1296541.55381], 'rh_bankssts_NumVert': ['1610'], 'rh_bankssts_SurfArea': ['872'], 'rh_bankssts_GrayVol': ['2084'], 'rh_bankssts_ThickAvg': ['2.470'], 'rh_bankssts_ThickStd': ['0.406'], 'rh_bankssts_MeanCurv': ['0.084'], 'rh_bankssts_GausCurv': ['0.016'], 'rh_bankssts_FoldInd': ['12'], 'rh_bankssts_CurvInd': ['1.1'], 'rh_caudalanteriorcingulate_NumVert': ['1454'], 'rh_caudalanteriorcingulate_SurfArea': ['738'], 'rh_caudalanteriorcingulate_GrayVol': ['2479'], 'rh_caudalanteriorcingulate_ThickAvg': ['2.577'], 'rh_caudalanteriorcingulate_ThickStd': ['0.963'], 'rh_caudalanteriorcingulate_MeanCurv': ['0.111'], 'rh_caudalanteriorcingulate_GausCurv': ['0.030'], 'rh_caudalanteriorcingulate_FoldInd': ['19'], 'rh_caudalanteriorcingulate_CurvInd': ['1.9'], 'rh_caudalmiddlefrontal_NumVert': ['3837'], 'rh_caudalmiddlefrontal_SurfArea': ['1950'], 'rh_caudalmiddlefrontal_GrayVol': ['5255'], 'rh_caudalmiddlefrontal_ThickAvg': ['2.434'], 'rh_caudalmiddlefrontal_ThickStd': ['0.502'], 'rh_caudalmiddlefrontal_MeanCurv': ['0.097'], 'rh_caudalmiddlefrontal_GausCurv': ['0.027'], 'rh_caudalmiddlefrontal_FoldInd': ['37'], 'rh_caudalmiddlefrontal_CurvInd': ['4.5'], 'rh_cuneus_NumVert': ['3110'], 'rh_cuneus_SurfArea': ['1465'], 'rh_cuneus_GrayVol': ['3779'], 'rh_cuneus_ThickAvg': ['2.143'], 'rh_cuneus_ThickStd': ['0.513'], 'rh_cuneus_MeanCurv': ['0.121'], 'rh_cuneus_GausCurv': ['0.036'], 'rh_cuneus_FoldInd': ['40'], 'rh_cuneus_CurvInd': ['4.9'], 'rh_entorhinal_NumVert': ['705'], 'rh_entorhinal_SurfArea': ['372'], 'rh_entorhinal_GrayVol': ['1737'], 'rh_entorhinal_ThickAvg': ['3.416'], 'rh_entorhinal_ThickStd': ['0.681'], 'rh_entorhinal_MeanCurv': ['0.100'], 'rh_entorhinal_GausCurv': ['0.026'], 'rh_entorhinal_FoldInd': ['6'], 'rh_entorhinal_CurvInd': ['0.8'], 'rh_fusiform_NumVert': ['5246'], 'rh_fusiform_SurfArea': ['2742'], 'rh_fusiform_GrayVol': ['9546'], 'rh_fusiform_ThickAvg': ['2.852'], 'rh_fusiform_ThickStd': ['0.682'], 'rh_fusiform_MeanCurv': ['0.119'], 'rh_fusiform_GausCurv': ['0.037'], 'rh_fusiform_FoldInd': ['74'], 'rh_fusiform_CurvInd': ['8.8'], 'rh_inferiorparietal_NumVert': ['8029'], 'rh_inferiorparietal_SurfArea': ['4192'], 'rh_inferiorparietal_GrayVol': ['12890'], 'rh_inferiorparietal_ThickAvg': ['2.522'], 'rh_inferiorparietal_ThickStd': ['0.655'], 'rh_inferiorparietal_MeanCurv': ['0.111'], 'rh_inferiorparietal_GausCurv': ['0.035'], 'rh_inferiorparietal_FoldInd': ['105'], 'rh_inferiorparietal_CurvInd': ['12.1'], 'rh_inferiortemporal_NumVert': ['5484'], 'rh_inferiortemporal_SurfArea': ['2854'], 'rh_inferiortemporal_GrayVol': ['10428'], 'rh_inferiortemporal_ThickAvg': ['2.872'], 'rh_inferiortemporal_ThickStd': ['0.769'], 'rh_inferiortemporal_MeanCurv': ['0.118'], 'rh_inferiortemporal_GausCurv': ['0.040'], 'rh_inferiortemporal_FoldInd': ['88'], 'rh_inferiortemporal_CurvInd': ['9.5'], 'rh_isthmuscingulate_NumVert': ['1650'], 'rh_isthmuscingulate_SurfArea': ['794'], 'rh_isthmuscingulate_GrayVol': ['2343'], 'rh_isthmuscingulate_ThickAvg': ['2.342'], 'rh_isthmuscingulate_ThickStd': ['0.829'], 'rh_isthmuscingulate_MeanCurv': ['0.118'], 'rh_isthmuscingulate_GausCurv': ['0.035'], 'rh_isthmuscingulate_FoldInd': ['24'], 'rh_isthmuscingulate_CurvInd': ['2.4'], 'rh_lateraloccipital_NumVert': ['9429'], 'rh_lateraloccipital_SurfArea': ['4779'], 'rh_lateraloccipital_GrayVol': ['13934'], 'rh_lateraloccipital_ThickAvg': ['2.416'], 'rh_lateraloccipital_ThickStd': ['0.648'], 'rh_lateraloccipital_MeanCurv': ['0.126'], 'rh_lateraloccipital_GausCurv': ['0.037'], 'rh_lateraloccipital_FoldInd': ['135'], 'rh_lateraloccipital_CurvInd': ['14.3'], 'rh_lateralorbitofrontal_NumVert': ['3557'], 'rh_lateralorbitofrontal_SurfArea': ['1862'], 'rh_lateralorbitofrontal_GrayVol': ['5793'], 'rh_lateralorbitofrontal_ThickAvg': ['2.666'], 'rh_lateralorbitofrontal_ThickStd': ['0.639'], 'rh_lateralorbitofrontal_MeanCurv': ['0.115'], 'rh_lateralorbitofrontal_Gau ...

# %%
import pandas as pd

subDf = pd.read_excel('核磁编号_tosangf.xlsx', header=0)
datDf = pd.read_csv('Res_atlas-aparc.csv', header=0)
datDf = datDf.set_index(['participant_id'])

datDf = datDf.loc[subDf['participant_id'].values, :]
datDf.to_csv('./Res_atlas-aparc_tolong.csv')
